# %%
import os
from PIL import Image
import cv2
import numpy as np
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
from part2 import get_output

def cv2_to_pil(cv2_image):
    """
    Convert CV2 image to PIL Image while preserving the original color space
    """
    if cv2_image.shape[2] == 3:
        # Convert BGR to RGB
        return Image.fromarray(cv2.cvtColor(cv2_image, cv2.COLOR_BGR2RGB))
    else:
        # If image is already in RGB or other format, convert directly
        return Image.fromarray(cv2_image)

def pil_to_cv2(pil_image):
    """
    Convert PIL Image to CV2 format while preserving the original color space
    """
    # Convert PIL image to numpy array
    numpy_image = np.array(pil_image)
    # Check if image is RGB
    if len(numpy_image.shape) == 3 and numpy_image.shape[2] == 3:
        # Convert RGB to BGR
        return cv2.cvtColor(numpy_image, cv2.COLOR_RGB2BGR)
    return numpy_image

def process_image_folder(input_folder, output_base_folder):
    """
    Process all images in the input folder and save extracted eyes to output folders
    while preserving original color format
    
    Args:
        input_folder: Path to folder containing raw images
        output_base_folder: Base path for output folders
    """
    # Create output folders
    left_eye_folder = os.path.join(output_base_folder, 'left_eyes')
    right_eye_folder = os.path.join(output_base_folder, 'right_eyes')
    annotated_folder = os.path.join(output_base_folder, 'annotated')
    
    # Create directories if they don't exist
    for folder in [left_eye_folder, right_eye_folder, annotated_folder]:
        os.makedirs(folder, exist_ok=True)
    
    # Supported image extensions
    valid_extensions = ('.jpg', '.jpeg', '.png', '.bmp')
    
    # Process each image in the input folder
    for filename in os.listdir(input_folder):
        if filename.lower().endswith(valid_extensions):
            try:
                # Full path to input image
                input_path = os.path.join(input_folder, filename)
                
                # Get base filename without extension
                base_name = os.path.splitext(filename)[0]
                
                # Read original image to get format
                original_image = Image.open(input_path)
                original_mode = original_image.mode
                
                # Process image and get results
                annotated_image, left_eye, right_eye = get_output(input_path)
                
                # Save annotated image
                annotated_pil = cv2_to_pil(annotated_image)
                annotated_pil = annotated_pil.convert(original_mode)
                annotated_path = os.path.join(annotated_folder, f"{base_name}_annotated{os.path.splitext(filename)[1]}")
                annotated_pil.save(annotated_path)
                
                # Save left eye if detected
                if left_eye is not None:
                    left_eye_pil = cv2_to_pil(left_eye)
                    left_eye_pil = left_eye_pil.convert(original_mode)
                    left_eye_path = os.path.join(left_eye_folder, f"{base_name}_left{os.path.splitext(filename)[1]}")
                    left_eye_pil.save(left_eye_path)
                
                # Save right eye if detected
                if right_eye is not None:
                    right_eye_pil = cv2_to_pil(right_eye)
                    right_eye_pil = right_eye_pil.convert(original_mode)
                    right_eye_path = os.path.join(right_eye_folder, f"{base_name}_right{os.path.splitext(filename)[1]}")
                    right_eye_pil.save(right_eye_path)
                
                print(f"Successfully processed {filename}")
                
            except Exception as e:
                print(f"Error processing {filename}: {str(e)}")
                continue

# %%
if __name__ == "__main__":
    # Define your input and output folders
    input_folder = "closed_images"  # Change this to your input folder path
    output_base_folder = "processed_eyes"  # Change this to your desired output base folder
    
    process_image_folder(input_folder, output_base_folder)
# Out:
# Successfully processed 1000_F_200511763_jnNJ91OYbSgj9C6sre6MgLS0OvQfAZ6j.jpg
# Successfully processed 166024_00_2x.jpg
# Successfully processed 1d98f704b6ac34d12db92d75dff8b1cd.jpg
# Successfully processed 229469602.jpg
# Successfully processed 248243671.jpg
# Successfully processed 360_F_182077758_xwAjhlIOuywFCiJPda6jNfq0UxrEtUgh.jpg
# Successfully processed 360_F_276371400_t9dtc2OOXwcq7mEY1JTuNxdT06nf63Np.jpg
# Successfully processed 360_F_74075491_ZjWKAfLrVklR63WgQy5jaR6gvX431cxR.jpg
# Successfully processed 4267750-young-beautiful-woman-with-her-eyes-closed-in-the-st.jpeg
# Successfully processed 4Tai Chi ELder-58.jpg
# Successfully processed 65869603e675c475ff28c708_withmeta.jpg
# Successfully processed 71562931.jpg
# Successfully processed a-good-day-starts-with-good-coffee.jpg
# Successfully processed attractive-black-lady-with-closed-eyes.jpg
# Successfully processed beautiful-emotional-afro-woman-with-perfect-make-up.jpg
# Successfully processed beautiful-woman-with-bright-make-up.jpg
# Successfully processed beauty-people-health-concept-young-woman-face-with-closed-ey (1).jpg
# Successfully processed beauty-people-health-concept-young-woman-face-with-closed-ey (2).jpg
# Successfully processed beauty-people-health-concept-young-woman-face-with-closed-ey (3).jpg
# Successfully processed beauty-people-health-concept-young-woman-face-with-closed-ey.jpg
# Successfully processed close-handsome-smiling-young-shirtless-600nw-1451164382.jpg
# Successfully processed close-up-black-mans-face_709984-3277.jpg
# Successfully processed close-up-calm-african-american-businessman-relaxing-daydream.jpg
# Successfully processed close-up-happy-young-caucasian-woman-isolated-blurred-backgr.jpg
# Successfully processed close-up-of-woman-with-eyes-closed-CAIF19787.jpg
# Successfully processed closeup-handsome-businessman-eyes-closed-260nw-142234237.jpg
# Successfully processed COLOURBOX14849345.jpg
# Successfully processed D943_195_603_1200.jpg
# Successfully processed depositphotos_129676220-stock-photo-handsome-man-with-eyes-c.jpg
# Successfully processed depositphotos_647892490-stock-photo-exhausted-sad-woman-alon.jpg
# Successfully processed depositphotos_69927987-stock-photo-unhappy-man-with-closed-e.jpg
# Successfully processed depositphotos_72069833-stock-photo-attractive-man-with-close.jpg
# Successfully processed dont-let-them-get-into-your-head.jpg
# Successfully processed dreadlocks-man-portrait-closed-eyes-unusual-people-vitiligo-.jpg
# Successfully processed excited-woman-smiling-against-gray-background.jpg
# Successfully processed eyes-shut.jpg
# Successfully processed f0038139-800px-wm.jpg
# Successfully processed face-of-a-beautiful-girl-with-closed-eyes-closeup.jpg
# Successfully processed feeling-fresh-and-confident.jpg
# Successfully processed girl-girl-young-women-with-closed-eyes-people-wellness-beaut.jpg
# Successfully processed happiness-happy-brunette-woman-smiling-260nw-1836394984.jpg
# Successfully processed happy-with-her-beauty-regime.jpg
# Successfully processed i-hope-you-glow-all-day.jpg
# Successfully processed image-handsome-concentrated-mature-man-600nw-1066310348.jpg
# Successfully processed IMG_4675-2-533x800.jpg
# Successfully processed joyful-natural-young-woman-smiling.jpg
# Successfully processed lovepik-asian-young-man-with-eyes-closed-picture_501493325.jpg
# Successfully processed lovepik-man-listening-with-closed-eyes-picture_501522675.jpg
# Successfully processed lovepik-woman-with-eyes-closed-picture_501475946.jpg
# Successfully processed man-with-his-eyes-closed-and-tongue-out-1684537309852.jpg
# Successfully processed marcelo-matarazzo-256593-unsplash.jpg
# Successfully processed natural-beauty-woman-laughing-with-joy.jpg
# Successfully processed peaceful-young-woman-with-eyes-closed.jpg
# Successfully processed people-happiness-indoor-photo-young-260nw-2408083801.jpg
# Successfully processed person_with_migraine_in_bed-1296x728-header.jpg
# Successfully processed photo-of-pretty-dark-skin-people-closed-eyes-fingers-in-ears.jpg
# Successfully processed portrait-beautiful-young-woman-with-clean-fresh-skin.jpg
# Successfully processed portrait-of-a-caucasian-real-man.jpg
# Successfully processed portrait-of-a-caucasian-real-young-man.jpg
# Successfully processed portrait-of-a-caucassian-man-closing-eyes-and-smiling.jpg
# Successfully processed portrait-of-a-girl-with-no-makeup.jpg
# Successfully processed portrait-of-a-real-caucasian-adult-woman-with-excited-expres.jpg
# Successfully processed portrait-of-a-woman.jpg
# Successfully processed portrait-of-a-young-american-man-with-closed-eyes.jpg
# Successfully processed portrait-of-a-young-caucassian-man-closing-eyes-and-smiling.jpg
# Successfully processed portrait-of-a-young-japanese-with-closed-eyes.jpg
# Successfully processed portrait-of-caucasian-young-woman-with-puffed-cheeks-and-anx.jpg
# Successfully processed portrait-of-handsome-millennial-man-with-closed-eyes.jpg
# Successfully processed portrait-of-real-caucasian-man-with-blank-expression-and-eye.jpg
# Successfully processed portrait-of-real-caucasian-man-with-happy-expression-and-eye.jpg
# Successfully processed portrait-of-real-hispanic-man-with-blank-expression-and-eyes.jpg
# Successfully processed portrait-of-young-man-smiling-to-camera.jpg
# Successfully processed portrait-of-young-man-with-closed-eyes-DISF002247.jpg
# Successfully processed portrait-of-young-smiling-woman-face-partially-covered-with-.jpg
# Successfully processed portrait-person-closed-eyes-260nw-75140209.jpg
# Successfully processed preview16.jpg
# Successfully processed real-man.jpg
# Successfully processed real-pakistani-man-with-excited-expression-and-eyes-closed.jpg
# Successfully processed serious-man-with-closed-eyes-close-up-D8E8XH.jpg
# Successfully processed serious-upset-person-closing-his-eyes-while-thinking-KH6HE7.jpg
# Successfully processed shes-got-that-smooth-skin-wed-all-love-to-have.jpg
# Successfully processed stay-calm-everything-will-be-alright.jpg
# Successfully processed stock-photo-latin-woman-smiles-happily-relaxed-with-her-eyes.jpg
# Successfully processed studio-portrait-of-real-mediterranean-young-woman-with-eyes-.jpg
# Successfully processed studio-shot-of-happy-young-woman-with-eyes-closed-daydreamin.jpg
# Successfully processed this-is-funny.jpg
# Successfully processed woman-beauty-portrait.jpg
# Successfully processed woman-face-hands-beauty-skin-care-makeup-eyes-closed-white.jpg
# Successfully processed young-blond-handsome-man-with-curly-hair-wearing-casual-swea.jpg
# Successfully processed young-mexican-woman-portrait.jpg
# Successfully processed young-woman-beauty-portrait.jpg
# Successfully processed zen-meditation-face-man-meditating-600nw-2262798429.jpg
